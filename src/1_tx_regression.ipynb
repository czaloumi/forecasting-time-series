# %%
import pandas as pd
pd.pandas.set_option('display.max_columns', None)
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import seaborn as sns
import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from xgboost.sklearn import XGBRegressor

from helper_functions import *
import pickle

# %%
model('tx', LinearRegression())
# Out:
# RMSE: 373.16168075438435
# R2 Score: 0.5598872223770821

# %%
model('tx', RandomForestRegressor())
# Out:
# RMSE: 450.9837547638335
# R2 Score: 0.3571765776472232

# %%
model('tx', XGBRegressor())
# Out:
# RMSE: 553.2216025320583
# R2 Score: 0.03268447704305655

# %%
scores_df = pd.read_csv('../data/model_scores.csv')
scores_df
# Out:
#    LinearRegression_ca  RandomForestRegressor_ca  XGBRegressor_ca  \
# 0           734.065955                756.878265       835.030531
# 1             0.370678                  0.330956         0.185657
#
#    LinearRegression_tx  RandomForestRegressor_tx  XGBRegressor_tx
# 0           373.161681                450.983755       553.221603
# 1             0.559887                  0.357177         0.032684

# %%
scores_df.drop(['LinearRegression_ca','RandomForestRegressor_ca','XGBRegressor_ca'], axis=1, inplace=True)
scores_df
# Out:
#    LinearRegression_tx  RandomForestRegressor_tx  XGBRegressor_tx
# 0           373.161681                450.983755       553.221603
# 1             0.559887                  0.357177         0.032684

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(scores_df.columns[::-1], np.sort(scores_df.iloc[0]/scores_df.iloc[0].sum())[::-1], label='RMSE', color=gen_random_color(), width=0.5)
ax.plot(range(0, len(scores_df.columns)), scores_df.iloc[1][::-1], label='R2', color=gen_random_color())
ax.set_title('TX Item Sales Forecasting\nOut of Box Model Comparison')
ax.set_xlabel('Models')
ax.set_ylabel('Normalized Scores')
ax.legend()
plt.savefig('../images/tx_oob_regr_comparison.png');
