# %%
import pandas as pd
pd.pandas.set_option('display.max_columns', None)
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')
import seaborn as sns
import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.ensemble import RandomForestRegressor
from xgboost.sklearn import XGBRegressor

from helper_functions import *
import pickle

# %% [markdown]
# ### See `helper_functions.py` for details on `model` function.

# %%
model('ca', LinearRegression())
# Out:
# RMSE: 734.0659554863445
# R2 Score: 0.3706779436937887

# %%
model('ca', RandomForestRegressor())
# Out:
# RMSE: 766.708134296101
# R2 Score: 0.31346461050406393

# %%
model('ca', XGBRegressor())
# Out:
# RMSE: 835.0305312204143
# R2 Score: 0.18565675703137607

# %%
scores_df = pd.read_csv('../data/model_scores.csv')
scores_df
# Out:
#    LinearRegression_ca  RandomForestRegressor_ca  XGBRegressor_ca
# 0           734.065955                757.174132       835.030531
# 1             0.370678                  0.330433         0.185657

# %%
fig, ax = plt.subplots(figsize=(12, 6))
ax.bar(scores_df.columns[::-1], np.sort(scores_df.iloc[0]/scores_df.iloc[0].sum())[::-1], label='RMSE', color=gen_random_color(), width=0.5)
ax.plot(range(0, len(scores_df.columns)), scores_df.iloc[1][::-1], label='R2', color=gen_random_color())
ax.set_title('CA Item Sales Forecasting\nOut of Box Model Comparison')
ax.set_xlabel('Models')
ax.set_ylabel('Normalized Scores')
ax.legend()
plt.savefig('../images/oob_regr_comparison.png');
